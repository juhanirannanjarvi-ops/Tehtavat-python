# %%
#1.
number1 = 5
number2 = 5
if number1 == number2:
    print("number1 is equal to number 2")
elif number1 > number2:
    print("number1 is greater than number2")
elif number1 >= number2:
    print("number1 is equal to number2")
else: 
    print("number1 is NOT equal to number2")
# Out:
# number1 is equal to number 2

# %%
#2.
number1 = 7
number2 = 7
number3 = 7
if number1 == number2 == number3:
    print("All numbers are equal")
    
if number1 == number2 or number2 == number3:
    print("number1 and number 2 are equal OR number2 and number 3 are equal")
    
number1 = 9
number2 = 5
number3 = 3

if number1 > number2 and number1 > number3:
    print("number1 ios greater than both number2 and number3")
# Out:
# All numbers are equal
# number1 and number 2 are equal OR number2 and number 3 are equal
# number1 ios greater than both number2 and number3

# %%
#3.
name1 = "Markus"
name2 = "Jope"
name3 = "Valtteri"

if name1 == name2:
    print("name1 and name2 are equal")
    
if name1 != name2:
    print("name1 and name2 are not equal")
    
if name1 == name2:
    print("name1 and name2 are equal")
else:
    if name1 == name3:
        print("name1 and name3 are equal")
# Out:
# name1 and name2 are not equal
