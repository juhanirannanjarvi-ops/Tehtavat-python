# %%
## 1-3.
furniture = ["table", "chair", "shelf"]

print (furniture) #prints all elements
print (furniture [0]) # prints the first element
print (furniture [1]) # prints the second element
# Out:
# ['table', 'chair', 'shelf']
# table
# chair

# %%
## 4.
furniture = ["table", "chair", "shelf","sofa"]
for furniture in furniture:
    if furniture == "sofa": #if statement to check for sofa
        print(furniture)
# Out:
# sofa

# %%
## Excercise 2
import random
dices = ["1","2","3","4","5"] # 5 elements list for dices
print(random.randint(1, 5)) #random number from 1-5 that changes every print
print(dices) # print the whole list
# Out:
# 3
# ['1', '2', '3', '4', '5']
