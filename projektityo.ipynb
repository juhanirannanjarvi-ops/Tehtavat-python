# %%
import pandas as pd
import numpy as np

df = pd.read_csv('netflix_titles.csv')

# %%
df.head(10)
df.shape[0]
print(df.head(10),"Ensimmäiset 10 riviä pandas dataframea nimeltään df")
print(df.shape[0],"Näyttää rivien määrän")
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
df.shape[1]
print(df.shape[1],"Palauttaa sarakkeiden määrän")
# Out:
# 12 Palauttaa sarakkeiden määrän

# %%
missing_count = df.isnull().sum()
print(missing_count)
print("Selvietään kuinka monta dataa puutuu per sarake")
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64
# Selvietään kuinka monta dataa puutuu per sarake

# %%
import numpy as np
total_data=np.prod(df.shape)
total_missing=missing_count.sum()
per_of_missing_data=(total_missing/total_data)* 100
print(per_of_missing_data)
# Out:
# 4.075356723818175
